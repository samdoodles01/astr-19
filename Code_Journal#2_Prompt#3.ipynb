# %%
# Cell 1: Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Cell 2: Generate 1000 random numbers uniformly distributed in [0, 1]
random_numbers = np.random.uniform(0, 1, 1000)

# %%
# Cell 3: Create a histogram with 100 bins, label axes, and save as PDF
plt.figure(figsize=(8, 5))
plt.hist(random_numbers, bins=100, color='skyblue', edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of 1000 Uniformly Distributed Random Numbers")
plt.grid(True)
plt.tight_layout()
plt.savefig("uniform_histogram.pdf")
plt.show()
