# %%
# Cell 1: Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Cell 2: Create a numpy array x ranging from 0 to 1 in 100 steps
x = np.linspace(0, 1, 100)

# %%
# Cell 3: Define a function that returns exp(x)
def exponential_function(x):
    return np.exp(x)

# %%
# Cell 4: Use the function to calculate y = exp(x)
y = exponential_function(x)

# %%
# Cell 5: Plot x vs. y with appropriate labels, and save as PDF
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='exp(x)')
plt.xlabel("Time [milliseconds]")
plt.ylabel("Awesomeness")
plt.title("Exponential Growth of Awesomeness Over Time")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("awesome_plot.pdf")
plt.show()
